# %%
from base_topo import Graph
from fat_tree_topo import FatTreeTopo
from jellyfist_topo import JellyFishTopo
from b_cube_topo import BCubeTopo
from d_cell_topo import DCellTopo
from composables.networkx_composable import NetworkxVisualizationComposer

import matplotlib.pyplot as plt
from collections import Counter
import pandas as pd

# %% [markdown]
# ## Comparison of various topologies

# %% [markdown]
# ### Visualising a n = 4 fat tree

# %%
ftt_4 = FatTreeTopo(4)
n_ftt_4 = NetworkxVisualizationComposer()
ftt_4.add_composable(n_ftt_4)

ftt_4.generate_fat_tree_structure()
n_ftt_4.draw("neato")

# %% [markdown]
# ### Visualising a n = 4 jelly fish

# %%
jf_4 = JellyFishTopo(4)
n_jf_4 = NetworkxVisualizationComposer()
jf_4.add_composable(n_jf_4)

jf_4.generate_jellyfish_structure()

n_jf_4.draw("neato")

# %% [markdown]
# ### Visualising a n = 4 BCube

# %%
bc_4_1 = BCubeTopo(4, 1)
n_bc_4_1 = NetworkxVisualizationComposer()
bc_4_1.add_composable(n_bc_4_1)

bc_4_1.generate_bcube_structure()
n_bc_4_1.draw()

# %% [markdown]
# ### Visualising a n = 4 DCell

# %%
dc_4_1 = DCellTopo(4, 1)
n_dc_4_1 = NetworkxVisualizationComposer()
dc_4_1.add_composable(n_dc_4_1)

dc_4_1.generate_dcell_structure(1)

n_dc_4_1.draw("neato")

# %% [markdown]
# ## Visualising Dijkstra for Fat tree and Jellyfish

# %% [markdown]
# * We compute a 686 version of Fat tree and Jelly Fish as per the paper

# %%
ftt_14 = FatTreeTopo(14)
n_ftt_14 = NetworkxVisualizationComposer()
ftt_14.add_composable(n_ftt_14)

ftt_14.generate_fat_tree_structure()

ftt_14.num_hosts
# Out:
# 686

# %%
jf_14 = JellyFishTopo(14)
n_jf_14 = NetworkxVisualizationComposer()
jf_14.add_composable(n_jf_14)

jf_14.generate_jellyfish_structure()

jf_14.num_hosts
# Out:
# 686

# %%
all_dj_ftt_14 = ftt_14.compute_dijikstra_for_all_hosts()
dj_ctr_all_dj_ftt_14 = Counter(all_dj_ftt_14)
# Out:
# parallelising using 8 cores
# host 1 of 686
# host 2 of 686
# host 3 of 686
# host 4 of 686
# host 5 of 686
# host 6 of 686
# host 7 of 686
# host 8 of 686
# host 9 of 686
# host 10 of 686
# host 11 of 686
# host 12 of 686
# host 13 of 686
# host 14 of 686
# host 15 of 686
# host 16 of 686
# host 17 of 686
# host 18 of 686
# host 19 of 686
# host 20 of 686
# host 21 of 686
# host 22 of 686
# host 23 of 686
# host 24 of 686
# host 25 of 686
# host 26 of 686
# host 27 of 686
# host 28 of 686
# host 29 of 686
# host 30 of 686
# host 31 of 686
# host 32 of 686
# host 33 of 686
# host 34 of 686
# host 35 of 686
# host 36 of 686
# host 37 of 686
# host 38 of 686
# host 39 of 686
# host 40 of 686
# host 41 of 686
# host 42 of 686
# host 43 of 686
# host 44 of 686
# host 45 of 686
# host 46 of 686
# host 47 of 686
# host 48 of 686
# host 49 of 686
# host 50 of 686
# host 51 of 686
# host 52 of 686
# host 53 of 686
# host 54 of 686
# host 55 of 686
# host 56 of 686
# host 57 of 686
# host 58 of 686
# host 59 of 686
# host 60 of 686
# host 61 of 686
# host 62 of 686
# host 63 of 686
# host 64 of 686
# host 65 of 686
# host 66 of 686
# host 67 of 686
# host 68 of 686
# host 69 of 686
# host 70 of 686
# host 71 of 686
# host 72 of 686
# host 73 of 686
# host 74 of 686
# host 75 of 686
# host 76 of 686
# host 77 of 686
# host 78 of 686
# host 79 of 686
# host 80 of 686
# host 81 of 686
# host 82 of 686
# host 83 of 686
# host 84 of 686
# host 85 of 686
# host 86 of 686
# host 87 of 686
# host 88 of 686
# host 89 of 686
# host 90 of 686
# host 91 of 686
# host 92 of 686
# host 93 of 686
# host 94 of 686
# host 95 of 686
# host 96 of 686
# host 97 of 686
# host 98 of 686
# host 99 of 686
# host 100 of 686
# host 101 of 686
# host 102 of 686
# host 103 of 686
# host 104 of 686
# host 105 of 686
# host 106 of 686
# host 107 of 686
# host 108 of 686
# host 109 of 686
# host 110 of 686
# host 111 of 686
# host 112 of 686
# host 113 of 686
# host 114 of 686
# host 115 of 686
# host 116 of 686
# host 117 of 686
# host 118 of 686
# host 119 of 686
# host 120 of 686
# host 121 of 686
# host 122 of 686
# host 123 of 686
# host 124 of 686
# host 125 of 686
# host 126 of 686
# host 127 of 686
# host 128 of 686
# host 129 of 686
# host 130 of 686
# host 131 of 686
# host 132 of 686
# host 133 of 686
# host 134 of 686
# host 135 of 686
# host 136 of 686
# host 137 of 686
# host 138 of 686
# host 139 of 686
# host 140 of 686
# host 141 of 686
# host 142 of 686
# host 143 of 686
# host 144 of 686
# host 145 of 686
# host 146 of 686
# host 147 of 686
# host 148 of 686
# host 149 of 686
# host 150 of 686
# host 151 of 686
# host 152 of 686
# host 153 of 686
# host 154 of 686
# host 155 of 686
# host 156 of 686
# host 157 of 686
# host 158 of 686
# host 159 of 686
# host 160 of 686
# host 161 of 686
# host 162 of 686
# host 163 of 686
# host 164 of 686
# host 165 of 686
# host 166 of 686
# host 167 of 686
# host 168 of 686
# host 169 of 686
# host 170 of 686
# host 171 of 686
# host 172 of 686
# host 173 of 686
# host 174 of 686
# host 175 of 686
# host 176 of 686
# host 177 of 686
# host 178 of 686
# host 179 of 686
# host 180 of 686
# host 181 of 686
# host 182 of 686
# host 183 of 686
# host 184 of 686
# host 185 of 686
# host 186 of 686
# host 187 of 686
# host 188 of 686
# host 189 of 686
# host 190 of 686
# host 191 of 686
# host 192 of 686
# host 193 of 686
# host 194 of 686
# host 195 of 686
# host 196 of 686
# host 197 of 686
# host 198 of 686
# host 199 of 686
# host 200 of 686
# host 201 of 686
# host 202 of 686
# host 203 of 686
# host 204 of 686
# host 205 of 686
# host 206 of 686
# host 207 of 686
# host 208 of 686
# host 209 of 686
# host 210 of 686
# host 211 of 686
# host 212 of 686
# host 213 of 686
# host 214 of 686
# host 215 of 686
# host 216 of 686
# host 217 of 686
# host 218 of 686
# host 219 of 686
# host 220 of 686
# host 221 of 686
# host 222 of 686
# host 223 of 686
# host 224 of 686
# host 225 of 686
# host 226 of 686
# host 227 of 686
# host 228 of 686
# host 229 of 686
# host 230 of 686
# host 231 of 686
# host 232 of 686
# host 233 of 686
# host 234 of 686
# host 235 of 686
# host 236 of 686
# host 237 of 686
# host 238 of 686
# host 239 of 686
# host 240 of 686
# host 241 of 686
# host 242 of 686
# host 243 of 686
# host 244 of 686
# host 245 of 686
# host 246 of 686
# host 247 of 686
# host 248 of 686
# host 249 of 686
# host 250 of 686
# host 251 of 686
# host 252 of 686
# host 253 of 686
# host 254 of 686
# host 255 of 686
# host 256 of 686
# host 257 of 686
# host 258 of 686
# host 259 of 686
# host 260 of 686
# host 261 of 686
# host 262 of 686
# host 263 of 686
# host 264 of 686
# host 265 of 686
# host 266 of 686
# host 267 of 686
# host 268 of 686
# host 269 of 686
# host 270 of 686
# host 271 of 686
# host 272 of 686
# host 273 of 686
# host 274 of 686
# host 275 of 686
# host 276 of 686
# host 277 of 686
# host 278 of 686
# host 279 of 686
# host 280 of 686
# host 281 of 686
# host 282 of 686
# host 283 of 686
# host 284 of 686
# host 285 of 686
# host 286 of 686
# host 287 of 686
# host 288 of 686
# host 289 of 686
# host 290 of 686
# host 291 of 686
# host 292 of 686
# host 293 of 686
# host 294 of 686
# host 295 of 686
# host 296 of 686
# host 297 of 686
# host 298 of 686
# host 299 of 686
# host 300 of 686
# host 301 of 686
# host 302 of 686
# host 303 of 686
# host 304 of 686
# host 305 of 686
# host 306 of 686
# host 307 of 686
# host 308 of 686
# host 309 of 686
# host 310 of 686
# host 311 of 686
# host 312 of 686
# host 313 of 686
# host 314 of 686
# host 315 of 686
# host 316 of 686
# host 317 of 686
# host 318 of 686
# host 319 of 686
# host 320 of 686
# host 321 of 686
# host 322 of 686
# host 323 of 686
# host 324 of 686
# host 325 of 686
# host 326 of 686
# host 327 of 686
# host 328 of 686
# host 329 of 686
# host 330 of 686
# host 331 of 686
# host 332 of 686
# host 333 of 686
# host 334 of 686
# host 335 of 686
# host 336 of 686
# host 337 of 686
# host 338 of 686
# host 339 of 686
# host 340 of 686
# host 341 of 686
# host 342 of 686
# host 343 of 686
# host 344 of 686
# host 345 of 686
# host 346 of 686
# host 347 of 686
# host 348 of 686
# host 349 of 686
# host 350 of 686
# host 351 of 686
# host 352 of 686
# host 353 of 686
# host 354 of 686
# host 355 of 686
# host 356 of 686
# host 357 of 686
# host 358 of 686
# host 359 of 686
# host 360 of 686
# host 361 of 686
# host 362 of 686
# host 363 of 686
# host 364 of 686
# host 365 of 686
# host 366 of 686
# host 367 of 686
# host 368 of 686
# host 369 of 686
# host 370 of 686
# host 371 of 686
# host 372 of 686
# host 373 of 686
# host 374 of 686
# host 375 of 686
# host 376 of 686
# host 377 of 686
# host 378 of 686
# host 379 of 686
# host 380 of 686
# host 381 of 686
# host 382 of 686
# host 383 of 686
# host 384 of 686
# host 385 of 686
# host 386 of 686
# host 387 of 686
# host 388 of 686
# host 389 of 686
# host 390 of 686
# host 391 of 686
# host 392 of 686
# host 393 of 686
# host 394 of 686
# host 395 of 686
# host 396 of 686
# host 397 of 686host 398 of 686
#
# host 399 of 686
# host 400 of 686
# host 401 of 686
# host 402 of 686
# host 403 of 686
# host 404 of 686
# host 405 of 686
# host 406 of 686
# host 407 of 686
# host 408 of 686
# host 409 of 686
# host 410 of 686
# host 411 of 686
# host 412 of 686
# host 413 of 686
# host 414 of 686
# host 415 of 686
# host 416 of 686
# host 417 of 686
# host 418 of 686
# host 419 of 686
# host 420 of 686
# host 421 of 686
# host 422 of 686
# host 423 of 686
# host 424 of 686
# host 425 of 686
# host 426 of 686
# host 427 of 686
# host 428 of 686
# host 429 of 686
# host 430 of 686
# host 431 of 686
# host 432 of 686
# host 433 of 686
# host 434 of 686
# host 435 of 686
# host 436 of 686
# host 437 of 686
# host 438 of 686
# host 439 of 686
# host 440 of 686
# host 441 of 686
# host 442 of 686
# host 443 of 686
# host 444 of 686
# host 445 of 686
# host 446 of 686
# host 447 of 686
# host 448 of 686
# host 449 of 686
# host 450 of 686
# host 451 of 686
# host 452 of 686
# host 453 of 686
# host 454 of 686
# host 455 of 686
# host 456 of 686
# host 457 of 686
# host 458 of 686
# host 459 of 686
# host 460 of 686
# host 461 of 686
# host 462 of 686
# host 463 of 686
# host 464 of 686
# host 465 of 686
# host 466 of 686
# host 467 of 686
# host 468 of 686
# host 469 of 686
# host 470 of 686
# host 471 of 686
# host 472 of 686
# host 473 of 686
# host 474 of 686
# host 475 of 686
# host 476 of 686
# host 477 of 686
# host 478 of 686
# host 479 of 686
# host 480 of 686
# host 481 of 686
# host 482 of 686
# host 483 of 686
# host 484 of 686
# host 485 of 686
# host 486 of 686
# host 487 of 686
# host 488 of 686
# host 489 of 686
# host 490 of 686
# host 491 of 686
# host 492 of 686
# host 493 of 686
# host 494 of 686
# host 495 of 686
# host 496 of 686
# host 497 of 686
# host 498 of 686
# host 499 of 686
# host 500 of 686
# host 501 of 686
# host 502 of 686
# host 503 of 686
# host 504 of 686
# host 505 of 686
# host 506 of 686
# host 507 of 686
# host 508 of 686
# host 509 of 686
# host 510 of 686
# host 511 of 686
# host 512 of 686
# host 513 of 686
# host 514 of 686
# host 515 of 686
# host 516 of 686
# host 517 of 686
# host 518 of 686
# host 519 of 686
# host 520 of 686
# host 521 of 686
# host 522 of 686
# host 523 of 686
# host 524 of 686
# host 525 of 686
# host 526 of 686
# host 527 of 686
# host 528 of 686
# host 529 of 686
# host 530 of 686
# host 531 of 686
# host 532 of 686
# host 533 of 686
# host 534 of 686
# host 535 of 686
# host 536 of 686
# host 537 of 686
# host 538 of 686
# host 539 of 686
# host 540 of 686
# host 541 of 686
# host 542 of 686
# host 543 of 686
# host 544 of 686
# host 545 of 686
# host 546 of 686
# host 547 of 686
# host 548 of 686
# host 549 of 686
# host 550 of 686
# host 551 of 686
# host 552 of 686
# host 553 of 686
# host 554 of 686
# host 555 of 686
# host 556 of 686
# host 557 of 686
# host 558 of 686
# host 559 of 686
# host 560 of 686
# host 561 of 686
# host 562 of 686
# host 563 of 686
# host 564 of 686
# host 565 of 686
# host 566 of 686
# host 567 of 686
# host 568 of 686
# host 569 of 686
# host 570 of 686
# host 571 of 686
# host 572 of 686
# host 573 of 686
# host 574 of 686
# host 575 of 686
# host 576 of 686
# host 577 of 686
# host 578 of 686
# host 579 of 686
# host 580 of 686
# host 581 of 686
# host 582 of 686
# host 583 of 686
# host 584 of 686
# host 585 of 686
# host 586 of 686
# host 587 of 686
# host 588 of 686
# host 589 of 686
# host 590 of 686
# host 591 of 686
# host 592 of 686
# host 593 of 686
# host 594 of 686
# host 595 of 686
# host 596 of 686
# host 597 of 686
# host 598 of 686
# host 599 of 686
# host 600 of 686
# host 601 of 686
# host 602 of 686
# host 603 of 686
# host 604 of 686
# host 605 of 686
# host 606 of 686
# host 607 of 686
# host 608 of 686
# host 609 of 686
# host 610 of 686
# host 611 of 686
# host 612 of 686
# host 613 of 686
# host 614 of 686
# host 615 of 686
# host 616 of 686
# host 617 of 686
# host 618 of 686
# host 619 of 686
# host 620 of 686
# host 621 of 686
# host 622 of 686
# host 623 of 686
# host 624 of 686
# host 625 of 686
# host 626 of 686
# host 627 of 686
# host 628 of 686
# host 629 of 686
# host 630 of 686
# host 631 of 686
# host 632 of 686
# host 633 of 686
# host 634 of 686
# host 635 of 686
# host 636 of 686
# host 637 of 686
# host 638 of 686
# host 639 of 686
# host 640 of 686
# host 641 of 686
# host 642 of 686
# host 643 of 686
# host 644 of 686
# host 645 of 686
# host 646 of 686
# host 647 of 686
# host 648 of 686
# host 649 of 686
# host 650 of 686
# host 651 of 686
# host 652 of 686
# host 653 of 686
# host 654 of 686
# host 655 of 686
# host 656 of 686
# host 657 of 686
# host 658 of 686
# host 659 of 686
# host 660 of 686
# host 661 of 686
# host 662 of 686
# host 663 of 686
# host 664 of 686
# host 665 of 686
# host 666 of 686
# host 667 of 686
# host 668 of 686
# host 669 of 686
# host 670 of 686
# host 671 of 686
# host 672 of 686
# host 673 of 686
# host 674 of 686
# host 675 of 686
# host 676 of 686
# host 677 of 686
# host 678 of 686
# host 679 of 686
# host 680 of 686
# host 681 of 686
# host 682 of 686
# host 683 of 686
# host 684 of 686
# host 685 of 686
# host 686 of 686

# %%
all_dj_jf_14 = jf_14.compute_dijikstra_for_all_hosts()
dj_ctr_all_dj_jf_14 = Counter(all_dj_jf_14)
# Out:
# parallelising using 8 cores
# host 1 of 686
# host 2 of 686
# host 3 of 686
# host 4 of 686
# host 5 of 686
# host 6 of 686
# host 7 of 686
# host 8 of 686
# host 9 of 686
# host 10 of 686
# host 11 of 686
# host 12 of 686
# host 13 of 686
# host 14 of 686
# host 15 of 686host 16 of 686
#
# host 17 of 686
# host 18 of 686
# host 19 of 686
# host 20 of 686
# host 21 of 686
# host 22 of 686
# host 23 of 686
# host 24 of 686
# host 25 of 686
# host 26 of 686
# host 27 of 686
# host 28 of 686
# host 29 of 686
# host 30 of 686
# host 31 of 686
# host 32 of 686
# host 33 of 686
# host 34 of 686
# host 35 of 686
# host 36 of 686
# host 37 of 686
# host 38 of 686
# host 39 of 686
# host 40 of 686
# host 41 of 686
# host 42 of 686
# host 43 of 686
# host 44 of 686
# host 45 of 686
# host 46 of 686
# host 47 of 686
# host 48 of 686
# host 49 of 686
# host 50 of 686
# host 51 of 686
# host 52 of 686
# host 53 of 686
# host 54 of 686
# host 55 of 686
# host 56 of 686
# host 57 of 686
# host 58 of 686
# host 59 of 686
# host 60 of 686
# host 61 of 686
# host 62 of 686
# host 63 of 686
# host 64 of 686
# host 65 of 686
# host 66 of 686
# host 67 of 686
# host 68 of 686
# host 69 of 686host 70 of 686
#
# host 71 of 686
# host 72 of 686
# host 73 of 686
# host 74 of 686
# host 75 of 686
# host 76 of 686
# host 77 of 686
# host 78 of 686
# host 79 of 686
# host 80 of 686
# host 81 of 686
# host 82 of 686
# host 83 of 686
# host 84 of 686
# host 85 of 686
# host 86 of 686
# host 87 of 686
# host 88 of 686
# host 89 of 686
# host 90 of 686
# host 91 of 686
# host 92 of 686
# host 93 of 686
# host 94 of 686
# host 95 of 686
# host 96 of 686
# host 97 of 686
# host 98 of 686
# host 99 of 686
# host 100 of 686
# host 101 of 686
# host 102 of 686
# host 103 of 686
# host 104 of 686
# host 105 of 686
# host 106 of 686
# host 107 of 686
# host 108 of 686
# host 109 of 686
# host 110 of 686
# host 111 of 686
# host 112 of 686
# host 113 of 686
# host 114 of 686
# host 115 of 686
# host 116 of 686
# host 117 of 686
# host 118 of 686
# host 119 of 686
# host 120 of 686
# host 121 of 686
# host 122 of 686
# host 123 of 686
# host 124 of 686
# host 125 of 686
# host 126 of 686
# host 127 of 686
# host 128 of 686
# host 129 of 686
# host 130 of 686
# host 131 of 686
# host 132 of 686
# host 133 of 686
# host 134 of 686
# host 135 of 686
# host 136 of 686
# host 137 of 686
# host 138 of 686
# host 139 of 686
# host 140 of 686
# host 141 of 686
# host 142 of 686
# host 143 of 686
# host 144 of 686
# host 145 of 686
# host 146 of 686
# host 147 of 686
# host 148 of 686
# host 149 of 686
# host 150 of 686
# host 151 of 686
# host 152 of 686
# host 153 of 686
# host 154 of 686
# host 155 of 686
# host 156 of 686
# host 157 of 686
# host 158 of 686
# host 159 of 686
# host 160 of 686
# host 161 of 686
# host 162 of 686
# host 163 of 686
# host 164 of 686
# host 165 of 686
# host 166 of 686
# host 167 of 686
# host 168 of 686
# host 169 of 686
# host 170 of 686
# host 171 of 686
# host 172 of 686
# host 173 of 686
# host 174 of 686
# host 175 of 686
# host 176 of 686
# host 177 of 686
# host 178 of 686
# host 179 of 686
# host 180 of 686
# host 181 of 686
# host 182 of 686
# host 183 of 686
# host 184 of 686
# host 185 of 686
# host 186 of 686
# host 187 of 686
# host 188 of 686
# host 189 of 686
# host 190 of 686
# host 191 of 686
# host 192 of 686
# host 193 of 686
# host 194 of 686
# host 195 of 686
# host 196 of 686
# host 197 of 686
# host 198 of 686
# host 199 of 686
# host 200 of 686
# host 201 of 686
# host 202 of 686
# host 203 of 686
# host 204 of 686
# host 205 of 686
# host 206 of 686
# host 207 of 686
# host 208 of 686
# host 209 of 686
# host 210 of 686
# host 211 of 686
# host 212 of 686
# host 213 of 686
# host 214 of 686
# host 215 of 686
# host 216 of 686
# host 217 of 686
# host 218 of 686
# host 219 of 686
# host 220 of 686
# host 221 of 686
# host 222 of 686
# host 223 of 686
# host 224 of 686
# host 225 of 686
# host 226 of 686
# host 227 of 686
# host 228 of 686
# host 229 of 686
# host 230 of 686
# host 231 of 686
# host 232 of 686
# host 233 of 686
# host 234 of 686
# host 235 of 686
# host 236 of 686
# host 237 of 686
# host 238 of 686
# host 239 of 686
# host 240 of 686
# host 241 of 686
# host 242 of 686
# host 243 of 686
# host 244 of 686
# host 245 of 686
# host 246 of 686
# host 247 of 686
# host 248 of 686
# host 249 of 686
# host 250 of 686
# host 251 of 686
# host 252 of 686
# host 253 of 686
# host 254 of 686
# host 255 of 686
# host 256 of 686
# host 257 of 686
# host 258 of 686
# host 259 of 686
# host 260 of 686
# host 261 of 686
# host 262 of 686
# host 263 of 686
# host 264 of 686
# host 265 of 686
# host 266 of 686
# host 267 of 686
# host 268 of 686
# host 269 of 686
# host 270 of 686
# host 271 of 686
# host 272 of 686
# host 273 of 686
# host 274 of 686
# host 275 of 686
# host 276 of 686
# host 277 of 686
# host 278 of 686
# host 279 of 686
# host 280 of 686
# host 281 of 686
# host 282 of 686
# host 283 of 686
# host 284 of 686
# host 285 of 686
# host 286 of 686
# host 287 of 686
# host 288 of 686
# host 289 of 686
# host 290 of 686
# host 291 of 686
# host 292 of 686
# host 293 of 686
# host 294 of 686
# host 295 of 686
# host 296 of 686
# host 297 of 686
# host 298 of 686
# host 299 of 686
# host 300 of 686
# host 301 of 686
# host 302 of 686
# host 303 of 686
# host 304 of 686
# host 305 of 686
# host 306 of 686
# host 307 of 686
# host 308 of 686
# host 309 of 686
# host 310 of 686
# host 311 of 686
# host 312 of 686
# host 313 of 686
# host 314 of 686
# host 315 of 686
# host 316 of 686
# host 317 of 686
# host 318 of 686
# host 319 of 686
# host 320 of 686
# host 321 of 686
# host 322 of 686
# host 323 of 686
# host 324 of 686
# host 325 of 686
# host 326 of 686
# host 327 of 686
# host 328 of 686
# host 329 of 686
# host 330 of 686
# host 331 of 686
# host 332 of 686
# host 333 of 686
# host 334 of 686
# host 335 of 686
# host 336 of 686
# host 337 of 686
# host 338 of 686
# host 339 of 686
# host 340 of 686
# host 341 of 686
# host 342 of 686
# host 343 of 686
# host 344 of 686
# host 345 of 686
# host 346 of 686
# host 347 of 686
# host 348 of 686
# host 349 of 686
# host 350 of 686
# host 351 of 686
# host 352 of 686
# host 353 of 686
# host 354 of 686
# host 355 of 686
# host 356 of 686
# host 357 of 686
# host 358 of 686
# host 359 of 686
# host 360 of 686
# host 361 of 686
# host 362 of 686
# host 363 of 686
# host 364 of 686
# host 365 of 686
# host 366 of 686
# host 367 of 686
# host 368 of 686
# host 369 of 686
# host 370 of 686
# host 371 of 686
# host 372 of 686
# host 373 of 686
# host 374 of 686
# host 375 of 686
# host 376 of 686
# host 377 of 686
# host 378 of 686
# host 379 of 686
# host 380 of 686
# host 381 of 686
# host 382 of 686
# host 383 of 686
# host 384 of 686
# host 385 of 686
# host 386 of 686
# host 387 of 686
# host 388 of 686
# host 389 of 686
# host 390 of 686
# host 391 of 686
# host 392 of 686
# host 393 of 686
# host 394 of 686
# host 395 of 686
# host 396 of 686
# host 397 of 686
# host 398 of 686
# host 399 of 686
# host 400 of 686
# host 401 of 686
# host 402 of 686
# host 403 of 686
# host 404 of 686
# host 405 of 686
# host 406 of 686
# host 407 of 686
# host 408 of 686
# host 409 of 686
# host 410 of 686
# host 411 of 686
# host 412 of 686
# host 413 of 686
# host 414 of 686
# host 415 of 686
# host 416 of 686
# host 417 of 686
# host 418 of 686
# host 419 of 686
# host 420 of 686
# host 421 of 686
# host 422 of 686
# host 423 of 686
# host 424 of 686
# host 425 of 686
# host 426 of 686
# host 427 of 686
# host 428 of 686
# host 429 of 686
# host 430 of 686
# host 431 of 686
# host 432 of 686
# host 433 of 686
# host 434 of 686
# host 435 of 686
# host 436 of 686
# host 437 of 686
# host 438 of 686
# host 439 of 686
# host 440 of 686
# host 441 of 686
# host 442 of 686
# host 443 of 686
# host 444 of 686
# host 445 of 686
# host 446 of 686
# host 447 of 686
# host 448 of 686
# host 449 of 686
# host 450 of 686
# host 451 of 686
# host 452 of 686
# host 453 of 686
# host 454 of 686
# host 455 of 686
# host 456 of 686
# host 457 of 686
# host 458 of 686
# host 459 of 686
# host 460 of 686
# host 461 of 686
# host 462 of 686
# host 463 of 686
# host 464 of 686
# host 465 of 686
# host 466 of 686
# host 467 of 686
# host 468 of 686
# host 469 of 686
# host 470 of 686
# host 471 of 686
# host 472 of 686
# host 473 of 686
# host 474 of 686
# host 475 of 686
# host 476 of 686
# host 477 of 686
# host 478 of 686
# host 479 of 686
# host 480 of 686
# host 481 of 686
# host 482 of 686
# host 483 of 686
# host 484 of 686
# host 485 of 686
# host 486 of 686
# host 487 of 686
# host 488 of 686
# host 489 of 686
# host 490 of 686
# host 491 of 686
# host 492 of 686
# host 493 of 686
# host 494 of 686
# host 495 of 686
# host 496 of 686
# host 497 of 686
# host 498 of 686
# host 499 of 686
# host 500 of 686
# host 501 of 686
# host 502 of 686
# host 503 of 686
# host 504 of 686
# host 505 of 686
# host 506 of 686
# host 507 of 686
# host 508 of 686
# host 509 of 686
# host 510 of 686
# host 511 of 686
# host 512 of 686
# host 513 of 686
# host 514 of 686
# host 515 of 686
# host 516 of 686
# host 517 of 686
# host 518 of 686host 519 of 686
# host 520 of 686
# host 521 of 686
# host 522 of 686
# host 523 of 686
# host 524 of 686
# host 525 of 686
# host 526 of 686
# host 527 of 686
# host 528 of 686
# host 529 of 686
# host 530 of 686
# host 531 of 686
# host 532 of 686
# host 533 of 686
# host 534 of 686
# host 535 of 686
# host 536 of 686
# host 537 of 686
# host 538 of 686
# host 539 of 686
# host 540 of 686
# host 541 of 686
# host 542 of 686
# host 543 of 686
# host 544 of 686
# host 545 of 686
# host 546 of 686
# host 547 of 686
# host 548 of 686
# host 549 of 686
# host 550 of 686
# host 551 of 686
# host 552 of 686
# host 553 of 686
# host 554 of 686
# host 555 of 686
# host 556 of 686
# host 557 of 686
# host 558 of 686
# host 559 of 686
# host 560 of 686
# host 561 of 686
# host 562 of 686
# host 563 of 686
# host 564 of 686
# host 565 of 686
# host 566 of 686
# host 567 of 686
# host 568 of 686
# host 569 of 686
# host 570 of 686
# host 571 of 686
# host 572 of 686
# host 573 of 686
# host 574 of 686
# host 575 of 686
# host 576 of 686
# host 577 of 686
# host 578 of 686
# host 579 of 686
# host 580 of 686
# host 581 of 686
# host 582 of 686
# host 583 of 686
# host 584 of 686
# host 585 of 686host 586 of 686
#
# host 587 of 686
# host 588 of 686
# host 589 of 686
# host 590 of 686
# host 591 of 686
# host 592 of 686
# host 593 of 686
# host 594 of 686
# host 595 of 686
# host 596 of 686
# host 597 of 686
# host 598 of 686
# host 599 of 686
# host 600 of 686
# host 601 of 686
# host 602 of 686
# host 603 of 686
# host 604 of 686
# host 605 of 686
# host 606 of 686
# host 607 of 686
# host 608 of 686
# host 609 of 686
# host 610 of 686
# host 611 of 686
# host 612 of 686
# host 613 of 686
# host 614 of 686
# host 615 of 686
# host 616 of 686
# host 617 of 686
# host 618 of 686
# host 619 of 686
# host 620 of 686
# host 621 of 686
# host 622 of 686
# host 623 of 686
# host 624 of 686
# host 625 of 686
# host 626 of 686
# host 627 of 686
# host 628 of 686
# host 629 of 686
# host 630 of 686
# host 631 of 686
# host 632 of 686
# host 633 of 686
# host 634 of 686
# host 635 of 686
# host 636 of 686
# host 637 of 686
# host 638 of 686
# host 639 of 686
# host 640 of 686
# host 641 of 686
# host 642 of 686
# host 643 of 686
# host 644 of 686
# host 645 of 686
# host 646 of 686
# host 647 of 686
# host 648 of 686
# host 649 of 686
# host 650 of 686
# host 651 of 686
# host 652 of 686
# host 653 of 686
# host 654 of 686
# host 655 of 686
# host 656 of 686
# host 657 of 686
# host 658 of 686
# host 659 of 686
# host 660 of 686
# host 661 of 686
# host 662 of 686
# host 663 of 686
# host 664 of 686
# host 665 of 686
# host 666 of 686
# host 667 of 686
# host 668 of 686
# host 669 of 686
# host 670 of 686
# host 671 of 686
# host 672 of 686
# host 673 of 686
# host 674 of 686
# host 675 of 686
# host 676 of 686
# host 677 of 686
# host 678 of 686
# host 679 of 686
# host 680 of 686
# host 681 of 686
# host 682 of 686
# host 683 of 686
# host 684 of 686
# host 685 of 686
# host 686 of 686

# %%
pd_jf_ftt_merged = pd.concat(
    [
    pd.DataFrame.from_dict(dj_ctr_all_dj_ftt_14, orient='index', columns=['ftt_path_length']),
    pd.DataFrame.from_dict(dj_ctr_all_dj_jf_14, orient='index', columns=['jf_path_length'])
    ], 
    axis=1
)

# %%
pd_jf_ftt_merged = pd_jf_ftt_merged.fillna(0)

# %%
normalized_pf_jf_ftt = pd_jf_ftt_merged.div(pd_jf_ftt_merged.max().max(), axis=0).sort_index()

# %%
normalized_pf_jf_ftt
# Out:
#    ftt_path_length  jf_path_length
# 2         0.009419        0.004330
# 3         0.000000        0.081472
# 4         0.065934        0.747454
# 5         0.000000        0.242097
# 6         1.000000        0.000000

# %%
normalized_pf_jf_ftt.plot( kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# ## Visualizing dijkstra for all topologies

# %%
all_dj_ftt_4 = ftt_4.compute_dijikstra_for_all_hosts()
dj_ctr_all_dj_ftt_4 = Counter(all_dj_ftt_4)

all_dj_jf_4 = jf_4.compute_dijikstra_for_all_hosts()
dj_ctr_all_dj_jf_4 = Counter(all_dj_jf_4)

all_dj_bc_4_1 = bc_4_1.compute_dijikstra_for_all_hosts()
dj_ctr_all_dj_bc_4_1 = Counter(all_dj_bc_4_1)

all_dj_dc_4_1 = dc_4_1.compute_dijikstra_for_all_hosts()
dj_ctr_all_dj_dc_4_1 = Counter(all_dj_dc_4_1)
# Out:
# parallelising using 8 cores
# host 1 of 16
# host 2 of 16
# host 3 of 16
# host 4 of 16
# host 5 of 16
# host 6 of 16
# host 7 of 16
# host 8 of 16
# host 9 of 16
# host 10 of 16
# host 11 of 16
# host 12 of 16
# host 13 of 16
# host 14 of 16
# host 15 of 16
# host 16 of 16
# parallelising using 8 cores
# host 1 of 16
# host 2 of 16
# host 3 of 16
# host 4 of 16
# host 5 of 16
# host 6 of 16
# host 7 of 16
# host 8 of 16
# host 9 of 16
# host 10 of 16
# host 11 of 16
# host 12 of 16
# host 13 of 16
# host 14 of 16
# host 15 of 16
# host 16 of 16
# parallelising using 8 cores
# host 1 of 16
# host 2 of 16
# host 3 of 16
# host 4 of 16
# host 5 of 16
# host 6 of 16
# host 7 of 16
# host 8 of 16
# host 9 of 16
# host 10 of 16
# host 11 of 16
# host 12 of 16
# host 13 of 16
# host 14 of 16
# host 15 of 16
# host 16 of 16
# parallelising using 8 cores
# host 1 of 20
# host 2 of 20
# host 3 of 20
# host 4 of 20
# host 5 of 20
# host 6 of 20
# host 7 of 20
# host 8 of 20
# host 9 of 20
# host 10 of 20
# host 11 of 20
# host 12 of 20
# host 13 of 20
# host 14 of 20
# host 15 of 20
# host 16 of 20
# host 17 of 20
# host 18 of 20
# host 19 of 20
# host 20 of 20

# %%
pd_ftt_jf_dc_bc = pd.concat(
    [
        pd.DataFrame.from_dict(dj_ctr_all_dj_ftt_4, orient='index', columns=['ftt_path_length']),
        pd.DataFrame.from_dict(dj_ctr_all_dj_jf_4, orient='index', columns=['jf_path_length']),
        pd.DataFrame.from_dict(dj_ctr_all_dj_bc_4_1, orient='index', columns=['bc_path_length']),
        pd.DataFrame.from_dict(dj_ctr_all_dj_dc_4_1, orient='index', columns=['dc_path_length'])
    ],
    axis = 1
)

# %%
pd_ftt_jf_dc_bc = pd_ftt_jf_dc_bc.fillna(0)

# %%
normalized_pd_ftt_jf_dc_bc = pd_ftt_jf_dc_bc.div(pd_ftt_jf_dc_bc.max().max(), axis=0).sort_index()

# %%
normalized_pd_ftt_jf_dc_bc
# Out:
#    ftt_path_length  jf_path_length  bc_path_length  dc_path_length
# 1         0.000000        0.000000         0.00000        0.104167
# 2         0.083333        0.072917         0.40625        0.312500
# 3         0.000000        0.395833         0.00000        0.625000
# 4         0.166667        0.645833         0.53125        0.312500
# 5         0.000000        0.135417         0.00000        0.625000
# 6         1.000000        0.000000         0.31250        0.000000

# %%
normalized_pd_ftt_jf_dc_bc.plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# # ECMP

# %%
ftt_yen = ftt_4.compute_yen_for_server_permutation_pairs()
jf_yen = jf_4.compute_yen_for_server_permutation_pairs()
dc_yen = dc_4_1.compute_yen_for_server_permutation_pairs()
bc_yen = bc_4_1.compute_yen_for_server_permutation_pairs()
# Out:
# Computing for h_1:h_8
# Computing for h_2:h_2
# Computing for h_3:h_9
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/sy/9bzbhhdd6nx_ptt7x4h1yblm0000gn/T/ipykernel_73549/2338721804.py", line 1, in <module>
#     ftt_yen = ftt_4.compute_yen_for_server_permutation_pairs()
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laxmanvijay/Documents/Studies/MastersCE/Paderborn/Studies/ANS/Labs/DevContainer/labs/02/base_topo.py", line 328, in compute_yen_for_server_permutation_pairs
#     computed_paths[path_name] = self.compute_yen_ksp(h[0], h[1], 64)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laxmanvijay/Documents/Studies/MastersCE/Paderborn/Studies/ANS/Labs/DevContainer/labs/02/base_topo.py", line 284, in compute_yen_ksp
#     path_spur, prev_path_spur = self.compute_dijkstra_using_heap(node_spur, node_end)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laxmanvijay/Documents/Studies/MastersCE/Paderborn/Studies/ANS/Labs/DevContainer/labs/02/base_topo.py", line None, in compute_dijkstra_using_heap
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2144, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 792, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/stack_data/core.py", line 698, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/stack_data/core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/stack_data/core.py", line 628, in executing_piece
#     return only(
#            ^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/executing/executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
ftt_4_yen = ftt_4.compute_yen_for_server_permutation_pairs()
# Out:
# Computing for h_1:h_5
# Computing for h_2:h_13
# Computing for h_3:h_7
# Computing for h_4:h_10
# Computing for h_5:h_6
# Computing for h_6:h_9
# Computing for h_7:h_2
# Computing for h_8:h_15
# Computing for h_9:h_1
# Computing for h_10:h_12
# Computing for h_11:h_8
# Computing for h_12:h_14
# Computing for h_13:h_16
# Computing for h_14:h_4
# Computing for h_15:h_3
# Computing for h_16:h_11

# %%
jf_4_yen = jf_4.compute_yen_for_server_permutation_pairs()
# Out:
# Computing for h_1:h_8
# Computing for h_2:h_9
# Computing for h_3:h_11
# Computing for h_4:h_5
# Computing for h_5:h_2
# Computing for h_6:h_6
# Computing for h_7:h_10
# Computing for h_8:h_16
# Computing for h_9:h_1
# Computing for h_10:h_14
# Computing for h_11:h_4
# Computing for h_12:h_15
# Computing for h_13:h_12
# Computing for h_14:h_7
# Computing for h_15:h_13
# Computing for h_16:h_3

# %%
dc_4_yen = dc_4_1.compute_yen_for_server_permutation_pairs()
# Out:
# Computing for h_0:h_10
# Computing for h_2:h_0
# Computing for h_4:h_20
# Computing for h_6:h_4
# Computing for h_8:h_6
# Computing for h_10:h_28
# Computing for h_12:h_38
# Computing for h_14:h_24
# Computing for h_16:h_30
# Computing for h_18:h_26
# Computing for h_20:h_36
# Computing for h_22:h_8
# Computing for h_24:h_32
# Computing for h_26:h_14
# Computing for h_28:h_16
# Computing for h_30:h_34
# Computing for h_32:h_18
# Computing for h_34:h_22
# Computing for h_36:h_2
# Key not found for hosts: {host_pair[0].id} and {host_pair[1].id}
# Key not found for hosts: {host_pair[0].id} and {host_pair[1].id}

# %%
bc_4_yen = bc_4_1.compute_yen_for_server_permutation_pairs()
# Out:
# Computing for h_1:h_15
# Computing for h_2:h_4
# Computing for h_3:h_16
# Computing for h_4:h_14
# Computing for h_5:h_3
# Computing for h_6:h_10
# Computing for h_7:h_5
# Computing for h_8:h_13
# Computing for h_9:h_7
# Computing for h_10:h_8
# Computing for h_11:h_12
# Computing for h_12:h_6
# Computing for h_13:h_11
# Computing for h_14:h_1
# Computing for h_15:h_9
# Computing for h_16:h_2

# %%
ftt_4_centrality = {
    "8_shortest": ftt_4.calculate_centrality(ftt_4_yen[1]),
    "8_ecmp": ftt_4.calculate_centrality(ftt_4_yen[2]),
    "64_ecmp": ftt_4.calculate_centrality(ftt_4_yen[3])
}

jf_4_centrality = {
    "8_shortest": jf_4.calculate_centrality(jf_4_yen[1]),
    "8_ecmp": jf_4.calculate_centrality(jf_4_yen[2]),
    "64_ecmp": jf_4.calculate_centrality(jf_4_yen[3])
}

dc_4_centrality = {
    "8_shortest": dc_4_1.calculate_centrality(dc_4_yen[1]),
    "8_ecmp": dc_4_1.calculate_centrality(dc_4_yen[2]),
    "64_ecmp": dc_4_1.calculate_centrality(dc_4_yen[3])
}

bc_4_centrality = {
    "8_shortest": bc_4_1.calculate_centrality(bc_4_yen[1]),
    "8_ecmp": bc_4_1.calculate_centrality(bc_4_yen[2]),
    "64_ecmp": bc_4_1.calculate_centrality(bc_4_yen[3])
}

# %%
def inverse_centrality(centrality_map):
    temp_dict = {}
    for n, o in centrality_map.items():
        res = {}
        for k,v in o.items():
            res[v] = (res.get(v) or 0) + 1
        temp_dict[n] = res
    return temp_dict

# %%
pd.DataFrame(inverse_centrality(ftt_4_centrality)).fillna(0).sort_index().plot(title="ftt-4-ecmp")
# Out:
# <Axes: title={'center': 'ftt-4-ecmp'}>

# %%
pd.DataFrame(inverse_centrality(jf_4_centrality)).fillna(0).sort_index().plot(title="jf-4-ecmp")
# Out:
# <Axes: title={'center': 'jf-4-ecmp'}>

# %%
pd.DataFrame(inverse_centrality(dc_4_centrality)).fillna(0).sort_index().plot(title="dc-4-ecmp")
# Out:
# <Axes: title={'center': 'dc-4-ecmp'}>

# %%
pd.DataFrame(inverse_centrality(bc_4_centrality)).fillna(0).sort_index().plot(title="bc-4-ecmp")
# Out:
# <Axes: title={'center': 'bc-4-ecmp'}>
